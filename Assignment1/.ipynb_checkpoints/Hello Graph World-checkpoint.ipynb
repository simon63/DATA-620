# %% [markdown]
# ##  DATA620 - Assignment 1
# ###    Elina Azrilyan, Murat Akyildirim, Jack Russo, Simon U.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()
edges = [("Jane", "Ike"),
         ("Ike", "Heather"),
         ("Heather","Fernando"),
         ("Heather","Garth"),
         ("Fernando","Carol"),
         ("Fernando","Andre"),
         ("Fernando","Diane"),
         ("Fernando","Garth"),
         ("Garth","Ed"),
         ("Garth","Beverly"),
         ("Garth","Diane"),
         ("Ed","Beverly"),
         ("Ed","Diane"),
         ("Carol","Andre"),
         ("Carol","Diane"),
         ("Andre","Beverly"),
         ("Andre","Diane"),
         ("Beverly","Diane")
        ]
G.add_edges_from(edges)
nx.draw(G, with_labels=True, node_size=900, node_color='#e377c2', node_shape='s')
